# %% [markdown]
# # Importing Libraries 📖

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/marvel-vs-dc/db.csv

# %% [markdown]
# # Loading data ⭕

# %%
data = pd.read_csv('../input/marvel-vs-dc/db.csv', encoding = 'latin')

# %%
data
# Out:
#     Unnamed: 0                       Original Title Company  Rate  Metascore  \
# 0            1                             Iron Man  Marvel   7.9         79
# 1            2                  The Incredible Hulk  Marvel   6.7         61
# 2            3                           Iron Man 2  Marvel   7.0         57
# 3            4                                 Thor  Marvel   7.0         57
# 4            5   Captain America: The First Avenger  Marvel   6.9         66
# 5            6                         The Avengers  Marvel   8.0         69
# 6            7                       Iron Man Three  Marvel   7.2         62
# 7            8                 Thor: The Dark World  Marvel   6.9         54
# 8            9  Captain America: The Winter Soldier  Marvel   7.7         70
# 9           10              Guardians of the Galaxy  Marvel   8.0         76
# 10          11             Avengers: Age of Ultron   Marvel   7.3         66
# 11          12                              Ant-Man  Marvel   7.3         64
# 12          13           Captain America: Civil War  Marvel   7.8         75
# 13          14                       Doctor Strange  Marvel   7.5         72
# 14          15       Guardians of the Galaxy Vol. 2  Marvel   7.6         67
# 15          16               Spider-Man: Homecoming  Marvel   7.4         73
# 16          17                        Thor:Ragnarok  Marvel   7.9         74
# 17          18                        Black Panther  Marvel   7.3         88
# 18          19               Avengers: Infinity War  Marvel   8.5         68
# 19          20                 Ant-Man and the Wasp  Marvel   7.1         70
# 20          21                        Captain Marve  Marvel   6.9         64
# 21          22                    Avengers: Endgame  Marvel   8.5         78
# 22          23            Spider-Man: Far from Home  Marvel   7.6         69
# 23          24                             Catwoman      DC   3.3         27
# 24          25                        Batman Begins      DC   8.2         70
# 25          26                     Superman Returns      DC   6.0         72
# 26          27                      The Dark Knight      DC   9.0         84
# 27          28                             Watchmen      DC   7.6         56
# 28          29                           Jonah Hex       DC   4.7         33
# 29          30                        Green Lantern      DC   5.5         39
# 30          31                The Dark Knight Rises      DC   8.4         78
# 31          32                         Man of Steel      DC   7.1         55
# 32          33   Batman v Superman: Dawn of Justice      DC   6.5         44
# 33          34                       Suicide Squad       DC   6.0         40
# 34          35                         Wonder Woman      DC   7.4         76
# 35          36                       Justice League      DC   6.4         45
# 36          37                              Aquaman      DC   7.0         55
# 37          38                              Shazam!      DC   7.1         71
# 38          39                                Joker      DC   8.7         59
#
#    Minutes  Release      Budget  Opening Weekend USA  Gross USA  \
# 0      126     2008   140000000             98618668  318604126
# 1     112      2008   150000000             55414050  134806913
# 2     124      2010   200000000            128122480  312433331
# 3      115     2011  150000000              65723338  181030624
# 4      124     2011   140000000             65058524  176654505
# 5      143     2012   220000000            207438708  623357910
# 6      130     2013  200000000             174144585  409013994
# 7      112     2013   170000000             85737841  206362140
# 8      136     2014   170000000             95023721  259766572
# 9      121     2014   170000000             94320883  333176600
# 10     141     2015   250000000            191271109  459005868
# 11     117     2015   130000000             57225526  180202163
# 12     147     2016   250000000            179139142  408084349
# 13     115     2016   165000000             85058311  232641920
# 14     136     2017   200000000            146510104  389813101
# 15     133     2017  175000000             117027503  334201140
# 16     130     2017   180000000            122744989  315058289
# 17     134     2018   200000000            202003951  700059566
# 18     149     2018  321000000             257698183  678815482
# 19     118     2018   162000000             75812205  216648740
# 20     123     2019  175000000             153433423  426829839
# 21     181     2019   356000000            357115007  858373000
# 22     129     2019   160000000             92579212  390532085
# 23     104     2004   100000000             16728411   40202379
# 24     140     2005   150000000             48745440  206852432
# 25     154     2006   270000000             52535096  200081192
# 26     152     2008   185000000            158411483  535234033
# 27     162     2009   130000000             55214334  107509799
# 28      81     2010   47000000               5379365   10547117
# 29     114     2011   200000000             53174303  116601172
# 30     164     2012   250000000            160887295  448139099
# 31     143     2013   225000000            116619362  291045518
# 32     151     2016   250000000            166007347  330360194
# 33     123     2016   175000000            133682248  325100054
# 34     141     2017   149000000            103251471  412563408
# 35     120     2017   300000000             93842239  229024295
# 36     143     2018   160000000             67873522  335061807
# 37     132     2019   100000000             53505326  140371656
# 38     122     2019   55000000              96202337  333204580
#
#     Gross Worldwide
# 0         585366247
# 1         263427551
# 2         623933331
# 3         449326618
# 4         370569774
# 5        1518812988
# 6        1214811252
# 7         644783140
# 8         714421503
# 9         772776600
# 10       1402805868
# 11        519311965
# 12       1153296293
# 13        677718395
# 14        863756051
# 15        880166924
# 16        853977126
# 17       1346913161
# 18       2048359754
# 19        622674139
# 20       1128274794
# 21       2797800564
# 22       1131927996
# 23         82102379
# 24        373413297
# 25        391081192
# 26       1004934033
# 27        185258983
# 28         10903312
# 29        219851172
# 30       1081041287
# 31        668045518
# 32        873634919
# 33        746846894
# 34        821847012
# 35        657924295
# 36       1148161807
# 37        364571656
# 38       1060504580

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           39 non-null     int64
#  1   Original Title       39 non-null     object
#  2   Company              39 non-null     object
#  3   Rate                 39 non-null     float64
#  4   Metascore            39 non-null     int64
#  5   Minutes              39 non-null     object
#  6   Release              39 non-null     int64
#  7   Budget               39 non-null     object
#  8   Opening Weekend USA  39 non-null     int64
#  9   Gross USA            39 non-null     int64
#  10  Gross Worldwide      39 non-null     int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 3.5+ KB

# %%
data.columns.unique()
# Out:
# Index(['Unnamed: 0', 'Original Title', 'Company', 'Rate', 'Metascore',
#        'Minutes', 'Release', 'Budget', 'Opening Weekend USA', 'Gross USA',
#        'Gross Worldwide'],
#       dtype='object')

# %% [markdown]
# ## Removing columns that do not add any importance to analyse the dataset

# %%
data = data.drop(['Unnamed: 0', 'Original Title'], axis = 1)

# %%
data
# Out:
#    Company  Rate  Metascore Minutes  Release      Budget  Opening Weekend USA  \
# 0   Marvel   7.9         79     126     2008   140000000             98618668
# 1   Marvel   6.7         61    112      2008   150000000             55414050
# 2   Marvel   7.0         57    124      2010   200000000            128122480
# 3   Marvel   7.0         57     115     2011  150000000              65723338
# 4   Marvel   6.9         66     124     2011   140000000             65058524
# 5   Marvel   8.0         69     143     2012   220000000            207438708
# 6   Marvel   7.2         62     130     2013  200000000             174144585
# 7   Marvel   6.9         54     112     2013   170000000             85737841
# 8   Marvel   7.7         70     136     2014   170000000             95023721
# 9   Marvel   8.0         76     121     2014   170000000             94320883
# 10  Marvel   7.3         66     141     2015   250000000            191271109
# 11  Marvel   7.3         64     117     2015   130000000             57225526
# 12  Marvel   7.8         75     147     2016   250000000            179139142
# 13  Marvel   7.5         72     115     2016   165000000             85058311
# 14  Marvel   7.6         67     136     2017   200000000            146510104
# 15  Marvel   7.4         73     133     2017  175000000             117027503
# 16  Marvel   7.9         74     130     2017   180000000            122744989
# 17  Marvel   7.3         88     134     2018   200000000            202003951
# 18  Marvel   8.5         68     149     2018  321000000             257698183
# 19  Marvel   7.1         70     118     2018   162000000             75812205
# 20  Marvel   6.9         64     123     2019  175000000             153433423
# 21  Marvel   8.5         78     181     2019   356000000            357115007
# 22  Marvel   7.6         69     129     2019   160000000             92579212
# 23      DC   3.3         27     104     2004   100000000             16728411
# 24      DC   8.2         70     140     2005   150000000             48745440
# 25      DC   6.0         72     154     2006   270000000             52535096
# 26      DC   9.0         84     152     2008   185000000            158411483
# 27      DC   7.6         56     162     2009   130000000             55214334
# 28      DC   4.7         33      81     2010   47000000               5379365
# 29      DC   5.5         39     114     2011   200000000             53174303
# 30      DC   8.4         78     164     2012   250000000            160887295
# 31      DC   7.1         55     143     2013   225000000            116619362
# 32      DC   6.5         44     151     2016   250000000            166007347
# 33      DC   6.0         40     123     2016   175000000            133682248
# 34      DC   7.4         76     141     2017   149000000            103251471
# 35      DC   6.4         45     120     2017   300000000             93842239
# 36      DC   7.0         55     143     2018   160000000             67873522
# 37      DC   7.1         71     132     2019   100000000             53505326
# 38      DC   8.7         59     122     2019   55000000              96202337
#
#     Gross USA  Gross Worldwide
# 0   318604126        585366247
# 1   134806913        263427551
# 2   312433331        623933331
# 3   181030624        449326618
# 4   176654505        370569774
# 5   623357910       1518812988
# 6   409013994       1214811252
# 7   206362140        644783140
# 8   259766572        714421503
# 9   333176600        772776600
# 10  459005868       1402805868
# 11  180202163        519311965
# 12  408084349       1153296293
# 13  232641920        677718395
# 14  389813101        863756051
# 15  334201140        880166924
# 16  315058289        853977126
# 17  700059566       1346913161
# 18  678815482       2048359754
# 19  216648740        622674139
# 20  426829839       1128274794
# 21  858373000       2797800564
# 22  390532085       1131927996
# 23   40202379         82102379
# 24  206852432        373413297
# 25  200081192        391081192
# 26  535234033       1004934033
# 27  107509799        185258983
# 28   10547117         10903312
# 29  116601172        219851172
# 30  448139099       1081041287
# 31  291045518        668045518
# 32  330360194        873634919
# 33  325100054        746846894
# 34  412563408        821847012
# 35  229024295        657924295
# 36  335061807       1148161807
# 37  140371656        364571656
# 38  333204580       1060504580

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              39 non-null     object
#  1   Rate                 39 non-null     float64
#  2   Metascore            39 non-null     int64
#  3   Minutes              39 non-null     object
#  4   Release              39 non-null     int64
#  5   Budget               39 non-null     object
#  6   Opening Weekend USA  39 non-null     int64
#  7   Gross USA            39 non-null     int64
#  8   Gross Worldwide      39 non-null     int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# > All columns except 'Company' type should be converted to either float or int type

# %%
convert_dtype = {
    'Minutes' : int,
    'Budget' : int
}

data = data.astype(convert_dtype)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              39 non-null     object
#  1   Rate                 39 non-null     float64
#  2   Metascore            39 non-null     int64
#  3   Minutes              39 non-null     int64
#  4   Release              39 non-null     int64
#  5   Budget               39 non-null     int64
#  6   Opening Weekend USA  39 non-null     int64
#  7   Gross USA            39 non-null     int64
#  8   Gross Worldwide      39 non-null     int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# > Converted

# %%
data[data['Company'] == 'Marvel'].mean()
# Out:
# Rate                   7.478261e+00
# Metascore              6.865217e+01
# Minutes                1.302609e+02
# Release                2.014696e+03
# Budget                 1.927826e+08
# Opening Weekend USA    1.350966e+08
# Gross USA              3.715423e+08
# Gross Worldwide        9.819657e+08
# dtype: float64

# %%
data[data['Company'] == 'DC'].mean()
# Out:
# Rate                   6.806250e+00
# Metascore              5.650000e+01
# Minutes                1.341250e+02
# Release                2.012500e+03
# Budget                 1.716250e+08
# Opening Weekend USA    8.637872e+07
# Gross USA              2.538687e+08
# Gross Worldwide        6.056326e+08
# dtype: float64

# %% [markdown]
# # Graphs showing correlation 📈

# %%
plt.figure(figsize = (12, 10))
sns.barplot(x = 'Company', y = 'Rate', data = data)
plt.show()

# %%
plt.figure(figsize = (12, 10))
sns.barplot(x = 'Company', y = 'Metascore', data = data)
plt.show()

# %%
plt.figure(figsize = (12, 10))
sns.barplot(x = 'Company', y = 'Minutes', data = data)
plt.show()

# %%
plt.figure(figsize = (12, 10))
sns.barplot(x = 'Release', y = 'Rate', hue = 'Company', data = data)
plt.show()

# %%
plt.figure(figsize = (12, 10))
sns.barplot(x = 'Release', y = 'Metascore', hue = 'Company', data = data)
plt.show()

# %%
plt.figure(figsize = (12, 10))
sns.barplot(x = 'Release', y = 'Minutes', hue = 'Company', data = data)
plt.show()

# %%
plt.figure(figsize = (12, 10))
sns.barplot(x = 'Company', y = 'Budget', data = data)
plt.show()

# %%
plt.figure(figsize = (12, 10))
sns.barplot(x = 'Company', y = 'Gross Worldwide', data = data)
plt.show()

# %% [markdown]
# # Conclusion 🤔

# %% [markdown]
# * Avg. rating of Marvel is greater than DC.
# * Avg. metascore of Marvel is greater than DC.
# * Avg. duration of DC movies is greater than Marvel.
#
# * DC movies were released earlier than birth of Marvel, but since 2010 people tended to like Marvel more over the years.
# * Gradually duration of movies of Marvel increased and whereas of DC decreased.
#
# * Moreover, we can see that the avg. budget for Marvel was more than DC, but the outcome was also good as the Gross World was also high. So, it was worth it !!!

# %% [markdown]
# ### Well, in my opinion as per stats Marvel won 🤔 , but let's see how future places these two in the tough competiton.
